# %% [markdown]
# # Day 13 (Concatenating,Merging & Joining)-

# %%
import pandas as pd
import numpy as np

# %%
deliveries=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\deliveries (1).csv")
regs_1=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\reg-month1.csv")  #also called 'Nov'
regs_2=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\reg-month2.csv")  #also called 'Dec'
students=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\students.csv")
courses=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\courses.csv")
matches=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\matches.csv")

# %% [markdown]
# # 1)- Concatenating-

# %%
#Concatenating-
pd.concat([regs_1,regs_2])   #Concatenate the jan and feb. using concat() function.
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# ...

# %%
pd.concat([regs_1,regs_2]).shape
# Out:
# (53, 2)

# %%
pd.concat([regs_1,regs_2],ignore_index=True)  #using ignore_index- it's also concatenate index.
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
# Creating a multi-index with keys-
multiindex=pd.concat([regs_1,regs_2],keys=['regs_1','regs_2'])
multiindex.loc['regs_1']
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
#accessing a student-

multiindex.loc[('regs_1',15)]
# Out:
# student_id    24
# course_id      4
# Name: (regs_1, 15), dtype: int64

# %%
# Horizontally Concatenate  (adding column)-

pd.concat([regs_1,regs_2],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %% [markdown]
# # Merging in DataFrame-

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
# 1)- Inner()-
inner=students.merge(jan,how='inner',on='student_id')
inner
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            3      Parveen Bhalla        3          3
# 3            7        Tarun Thaker        9          8
# 4            7        Tarun Thaker        9         10
# 5           11  David Mukhopadhyay       20          7
# 6           13      Munni Varghese       24          3
# 7           15           Preet Sha       16          5
# 8           15           Preet Sha       16          1
# 9           16        Elias Dodiya       25          9
# 10          16        Elias Dodiya       25          5
# 11          17        Yasmin Palan        7          7
# 12          18     Fardeen Mahabir       13          6
# 13          18     Fardeen Mahabir       13          1
# 14          19        Qabeel Raman       12          4
# 15          19        Qabeel Raman       12          2
# ...

# %%
left=students.merge(regs_1,how='left',on='student_id')
left
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23        1.0
# 1            1       Kailash Harjo       23        6.0
# 2            2         Esha Butala        1        NaN
# 3            3      Parveen Bhalla        3        3.0
# 4            4         Marlo Dugal       14        NaN
# 5            5         Kusum Bahri        6        NaN
# 6            6  Lakshmi Contractor       10        NaN
# 7            7        Tarun Thaker        9        8.0
# 8            7        Tarun Thaker        9       10.0
# 9            8      Radheshyam Dey        5        NaN
# 10           9   Nitika Chatterjee        4        NaN
# 11          10      Aayushman Sant        8        NaN
# 12          11  David Mukhopadhyay       20        7.0
# 13          12          Radha Dutt       19        NaN
# 14          13      Munni Varghese       24        3.0
# 15          14    Pranab Natarajan       22        NaN
# ...

# %%
right=students.merge(regs_1,how='right',on='student_id')
right
# Out:
#     student_id                name  partner  course_id
# 0           23      Chhavi Lachman       18          1
# 1           15           Preet Sha       16          5
# 2           18     Fardeen Mahabir       13          6
# 3           23      Chhavi Lachman       18          4
# 4           16        Elias Dodiya       25          9
# 5           18     Fardeen Mahabir       13          1
# 6            1       Kailash Harjo       23          1
# 7            7        Tarun Thaker        9          8
# 8           22          Yash Sethi       21          3
# 9           15           Preet Sha       16          1
# 10          19        Qabeel Raman       12          4
# 11           1       Kailash Harjo       23          6
# 12           7        Tarun Thaker        9         10
# 13          11  David Mukhopadhyay       20          7
# 14          13      Munni Varghese       24          3
# 15          24        Radhika Suri       17          4
# ...

# %%
outer=students.merge(regs_1,how='outer',on='student_id')
outer
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23        1.0
# 1            1       Kailash Harjo       23        6.0
# 2            2         Esha Butala        1        NaN
# 3            3      Parveen Bhalla        3        3.0
# 4            4         Marlo Dugal       14        NaN
# 5            5         Kusum Bahri        6        NaN
# 6            6  Lakshmi Contractor       10        NaN
# 7            7        Tarun Thaker        9        8.0
# 8            7        Tarun Thaker        9       10.0
# 9            8      Radheshyam Dey        5        NaN
# 10           9   Nitika Chatterjee        4        NaN
# 11          10      Aayushman Sant        8        NaN
# 12          11  David Mukhopadhyay       20        7.0
# 13          12          Radha Dutt       19        NaN
# 14          13      Munni Varghese       24        3.0
# 15          14    Pranab Natarajan       22        NaN
# ...

# %%
#total revenue -

x=regs_1.merge(courses,how='inner',on='course_id')['price'].sum()
y=regs_2.merge(courses,how='inner',on='course_id')['price'].sum()
x+y
# Out:
# np.int64(154247)

# %%
# Find month by month revenue-

# regs_1=nov
# regs_2=dec

temp=pd.concat([regs_1,regs_2],keys=['regs_1','regs_2']).reset_index()
result=temp.merge(courses,on='course_id').groupby('level_0')['price'].sum()
result
# Out:
# level_0
# regs_1    89175
# regs_2    65072
# Name: price, dtype: int64

# %%
#Create a Registration table-
# Name->Course->Price-

regs_1.merge(students,how='inner',on='student_id').merge(courses,on='course_id')[['name','course_name','price']]
# Out:
#                   name       course_name  price
# 0       Chhavi Lachman            python   2499
# 1            Preet Sha           tableau   2499
# 2      Fardeen Mahabir          power bi   1899
# 3       Chhavi Lachman  machine learning   9999
# 4         Elias Dodiya            plotly    699
# 5      Fardeen Mahabir            python   2499
# 6        Kailash Harjo            python   2499
# 7         Tarun Thaker            pandas   1099
# 8           Yash Sethi     data analysis   4999
# 9            Preet Sha            python   2499
# 10        Qabeel Raman  machine learning   9999
# 11       Kailash Harjo          power bi   1899
# 12        Tarun Thaker           pyspark   2499
# 13  David Mukhopadhyay          ms sxcel   1599
# 14      Munni Varghese     data analysis   4999
# 15        Radhika Suri  machine learning   9999
# 16          Seema Kota            python   2499
# 17        Elias Dodiya           tableau   2499
# 18      Chhavi Lachman     data analysis   4999
# ...

# %%
# earning by each courses-

regs_1.merge(courses,on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
#Student entrolled in Both months-

x=np.intersect1d(regs_1['student_id'],regs_2['student_id'])
x
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23])

# %%
result=students[students['student_id'].isin(x)]
result
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
#student name with partner name-

#self join-

students.merge(students,how='inner',left_on='partner',right_on='student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
# find top 3 students who did most number entrollment.

x=regs_1.merge(students,on='student_id').groupby(['student_id','name'])['name'].count()
y=regs_2.merge(students,on='student_id').groupby(['student_id','name'])['name'].count()
x.add(y,fill_value=0).sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman      6.0
# 7           Tarun Thaker        5.0
# 14          Pranab Natarajan    4.0
# Name: name, dtype: float64

# %%
a=regs_1.merge(students,on='student_id').merge(courses,on='course_id').groupby(['student_id','name'])['price'].sum()
b=regs_2.merge(students,on='student_id').merge(courses,on='course_id').groupby(['student_id','name'])['price'].sum()

a.add(b, fill_value=0).sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman      22594.0
# 14          Pranab Natarajan    15096.0
# 19          Qabeel Raman        13498.0
# Name: price, dtype: float64
