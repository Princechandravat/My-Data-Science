# %% [markdown]
# # Day 14 (Series & Dataframes Important Methods)

# %%
import pandas as pd

# %%
movies=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\imdb-top-1000.csv")
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
#astype-

movies['Runtime'].astype('int16')  #this function convert the data in differents bits
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime, Length: 1000, dtype: int16

# %%
#between()-

movies['Runtime'].between(120,150)  #Runtime between 120-150 movies with boolean values.
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Runtime, Length: 1000, dtype: bool

# %%
#Drop_duplicate-

duplicates_drop=movies['Director'].drop_duplicates()  #drops the directors which have more than 1 movie
print(duplicates_drop)
print()
print("The no. after dropped duplicated  directors-->",duplicates_drop.size)  #size after dropped duplicate values.
# Out:
# 0            Frank Darabont
# 1      Francis Ford Coppola
# 2         Christopher Nolan
# 4              Sidney Lumet
# 5             Peter Jackson
#                ...
# 986            Martin Rosen
# 992     Wolfgang Reitherman
# 994          Richard Lester
# 995           Blake Edwards
# 996          George Stevens
# Name: Director, Length: 548, dtype: object
#
# The no. after dropped duplicated  directors--> 548

# %%
#isnull()-

movies.isnull()  #this function show NaN values in the form of booleans
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 0           False          False    False  False        False     False
# 1           False          False    False  False        False     False
# 2           False          False    False  False        False     False
# 3           False          False    False  False        False     False
# 4           False          False    False  False        False     False
# ..            ...            ...      ...    ...          ...       ...
# 995         False          False    False  False        False     False
# 996         False          False    False  False        False     False
# 997         False          False    False  False        False     False
# 998         False          False    False  False        False     False
# 999         False          False    False  False        False     False
#
#      Star1  No_of_Votes  Gross  Metascore
# 0    False        False  False      False
# ...

# %%
#isnull().sum()-

movies.isnull().sum()  #it show sum of nan values in each columns.
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# No_of_Votes        0
# Gross              0
# Metascore        157
# dtype: int64

# %%
#dropna()-

movies.dropna()  #this function drops all the mssing values.
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
#fillna()-   

movies.fillna(0)  #this function fill the Nan values with a specific value like-0

movies.fillna(method='ffill') #this used for fill the Nan values with forward value

movies.fillna(method='bfill') #this function used for fill the NaN value with Backward value
# Out:
# C:\Users\Prince Chandravat\AppData\Local\Temp\ipykernel_17252\218090845.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   movies.fillna(method='ffill') #this used for fill the Nan values with forward value
# C:\Users\Prince Chandravat\AppData\Local\Temp\ipykernel_17252\218090845.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   movies.fillna(method='bfill') #this function used for fill the NaN value with Backward value
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# ...

# %%
#isin()-

#Checks whether each element in a Series is contained in a given list or set, returning a Boolean Series

movies[movies['Released_Year'].isin(['2020','1972'])]
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 1                          The Godfather          1972      175      Crime
# 18                              Hamilton          2020      160  Biography
# 20                       Soorarai Pottru          2020      153      Drama
# 205                                 Soul          2020      100  Animation
# 285                   Viskningar och rop          1972       91      Drama
# 286                              Solaris          1972      167      Drama
# 420                               Sleuth          1972      138    Mystery
# 464                          Dil Bechara          2020      101     Comedy
# 539  Le charme discret de la bourgeoisie          1972      102     Comedy
# 540             Aguirre, der Zorn Gottes          1972       95     Action
# 612           The Trial of the Chicago 7          2020      129      Drama
# ...

# %%
#apply-

# Applies a given function to each element in the Series and returns a new Series with the results-
movies['Director'].apply(lambda x: x.split()[0])  #use a function for just first name of director by apply() function.
# Out:
# 0            Frank
# 1          Francis
# 2      Christopher
# 3          Francis
# 4           Sidney
#           ...
# 995          Blake
# 996         George
# 997           Fred
# 998         Alfred
# 999         Alfred
# Name: Director, Length: 1000, dtype: object

# %%
new=movies['Series_Title'][1]='Titanic'
new

#it changes permanent in original data- 'movies' so because we copy() function it creates a copy function and which dont effect on original data-

#Copy-

copy=movies['Series_Title'][1]='The Godfather'
copy
# Out:
# C:\Users\Prince Chandravat\AppData\Local\Temp\ipykernel_17252\531849087.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   new=movies['Series_Title'][1]='Titanic'
# ...

# %%
#Values_Count-

movies['Director'].value_counts().sort_values(ascending=False)  #it counts the movies of each director
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Akira Kurosawa      10
# Martin Scorsese     10
#                     ..
# Kinji Fukasaku       1
# Eric Bress           1
# Thomas Kail          1
# Irvin Kershner       1
# Lana Wachowski       1
# Name: count, Length: 548, dtype: int64

# %%
ipl=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['TossDecision'].value_counts()
# Out:
# <Axes: ylabel='count'>

# %%
# sort_values in dataframe-

ipl['Margin'].sort_values(ascending=False)
# Out:
# 329    146.0
# 388    144.0
# 949    140.0
# 453    138.0
# 597    130.0
#        ...
# 608      NaN
# 621      NaN
# 708      NaN
# 819      NaN
# 883      NaN
# Name: Margin, Length: 950, dtype: float64

# %%
movies.sort_values('Series_Title')
# Out:
#                     Series_Title Released_Year  Runtime      Genre  \
# 754         (500) Days of Summer          2009       95     Comedy
# 4                   12 Angry Men          1957       96      Crime
# 215             12 Years a Slave          2013      134  Biography
# 84                          1917          2019      119      Drama
# 114        2001: A Space Odyssey          1968      149  Adventure
# ..                           ...           ...      ...        ...
# 330                     Zootopia          2016      108  Animation
# 860                         Zulu          1964      138      Drama
# 772                    Zwartboek          2006      145      Drama
# 708            À bout de souffle          1960       90      Crime
# 211  Ôkami kodomo no Ame to Yuki          2012      117  Animation
#
#      IMDB_Rating         Director                 Star1  No_of_Votes  \
# 754          7.7        Marc Webb       Zooey Deschanel       472242
# ...

# %%
movies['Series_Title'].sort_values()
# Out:
# 754           (500) Days of Summer
# 4                     12 Angry Men
# 215               12 Years a Slave
# 84                            1917
# 114          2001: A Space Odyssey
#                   ...
# 330                       Zootopia
# 860                           Zulu
# 772                      Zwartboek
# 708              À bout de souffle
# 211    Ôkami kodomo no Ame to Yuki
# Name: Series_Title, Length: 1000, dtype: object

# %%
movies.sort_values(['Released_Year','Series_Title'],ascending=[True,False])
# Out:
#                      Series_Title Released_Year  Runtime      Genre  \
# 321  Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 127                       The Kid          1921       68     Comedy
# 568                     Nosferatu          1922       94    Fantasy
# 194                  Sherlock Jr.          1924       45     Action
# 193                 The Gold Rush          1925       95  Adventure
# ..                            ...           ...      ...        ...
# 20                Soorarai Pottru          2020      153      Drama
# 18                       Hamilton          2020      160  Biography
# 613                          Druk          2020      117     Comedy
# 464                   Dil Bechara          2020      101     Comedy
# 966                     Apollo 13            PG      140  Adventure
#
#      IMDB_Rating           Director                 Star1  No_of_Votes  \
# 321          8.1       Robert Wiene         Werner Krauss        57428
# ...
