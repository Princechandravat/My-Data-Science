# %% [markdown]
# # Reading CSV file in Pandas:-

# %% [markdown]
# # *A House Prediction CSV File:-

# %%
#Reading a House Prediction CSV File-

import pandas as pd         #Import pandas as pd
from io import StringIO  #Import StringIO 

#Reading a CSV File in pandas-
house_prediction=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\house-price-parquet.csv")   #Reading a CSV File

print(type(house_prediction))
house_prediction
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# ...

# %%
#READING SELECTED COLUMNS

# %%
# selecting only price,bedrooms,furnishingstatus

house_specific=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\house-price-parquet.csv",usecols=['price','furnishingstatus','bedrooms'])

house_specific
# Out:
#         price  bedrooms furnishingstatus
# 0    13300000         4        furnished
# 1    12250000         4        furnished
# 2    12250000         3   semi-furnished
# 3    12215000         4        furnished
# 4    11410000         4        furnished
# ..        ...       ...              ...
# 540   1820000         2      unfurnished
# 541   1767150         3   semi-furnished
# 542   1750000         2      unfurnished
# 543   1750000         3        furnished
# 544   1750000         3      unfurnished
#
# [545 rows x 3 columns]

# %%
#READING WITH INDEX_COLUMN:-

# %%
#It is used when we want column as index-

# Setting index column while reading
df_indexed = pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\house-price-parquet.csv", index_col=['price'])  #price set as an index.

df_indexed
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 13300000  7420         4          2        3      yes        no       no
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
# 12215000  7500         4          2        2      yes        no      yes
# 11410000  7420         4          1        2      yes       yes      yes
# ...        ...       ...        ...      ...      ...       ...      ...
# 1820000   3000         2          1        1      yes        no      yes
# 1767150   2400         3          1        1       no        no       no
# 1750000   3620         2          1        1      yes        no       no
# 1750000   2910         3          1        1       no        no       no
# 1750000   3850         3          1        2      yes        no       no
#
#          hotwaterheating airconditioning  parking prefarea furnishingstatus
# price
# ...

# %%
# info/describe/head.

#use only price column
house_prices=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\house-price-parquet.csv",usecols=['price'])
house_prices

print(house_prices.head())   #starting 5 indexes of price

print()

print(house_prices.info())    #info of price

print()

print(house_prices.describe())
# Out:
#       price
# 0  13300000
# 1  12250000
# 2  12250000
# 3  12215000
# 4  11410000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   545 non-null    int64
# dtypes: int64(1)
# memory usage: 4.4 KB
# None
#
#               price
# count  5.450000e+02
# mean   4.766729e+06
# std    1.870440e+06
# min    1.750000e+06
# 25%    3.430000e+06
# 50%    4.340000e+06
# 75%    5.740000e+06
# max    1.330000e+07

# %%
#Slicing of csv file-

house_prediction[3:22]  #slicing from 3-21.
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes       yes      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# 9    9800000   5750         3          2        4      yes       yes       no
# 10   9800000  13200         3          1        2      yes        no      yes
# 11   9681000   6000         4          3        2      yes       yes      yes
# 12   9310000   6550         4          2        2      yes        no       no
# 13   9240000   3500         4          2        2      yes        no       no
# ...

# %%
# min/max/prod-

print(house_prices.min())    #minimum price of house
print(house_prices.max())   #maximum price of house
print(house_prices.prod())   #product of house
# Out:
# price    1750000
# dtype: int64
# price    13300000
# dtype: int64
# price    0
# dtype: int64

# %%
Students_data=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\titanic-parquet.csv")
Students_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 Students_data=pd.read_csv("C:\\Users\\Prince Chandravat\\Downloads\\titanic-parquet.csv")
#       2 Students_data.head()
#
# File ~\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# # Writing CSV File in Pandas:-

# %%
# Creating CSV DataFrame using stringIO-

import pandas as pd
from io import StringIO

# Define the CSV data as a multiline string
data = """Name,Age,City
Prince,20,Delhi
Keshav,21,Gurugram
Hritik,22,Jaipur
Devesh,20,Mumbai
Kartik,22,Agra"""

# Create an in-memory file-like buffer
csv_buffer = StringIO(data)

# Read the CSV data into a pandas DataFrame
df = pd.read_csv(csv_buffer)

# Display the resulting DataFrame
df

# %%
#Basic CSV Writing-
import pandas as pd

#Creating dataFrame
data = {
    'Name': ['Prince chandravat', 'Shruti khapra', 'Vibhor sharma'],
    'Age': [25, 30, 22],
    'City': ['Delhi', 'Mumbai', 'Bangalore']
}
df = pd.DataFrame(data)

#Write to csv
df.to_csv('basic_data.csv')

#Check
df.head()
# Out:
#                 Name  Age       City
# 0  Prince chandravat   25      Delhi
# 1      Shruti khapra   30     Mumbai
# 2      Vibhor sharma   22  Bangalore

# %%
#Writing without indexing-

data={
    'Name':['Prince','Gaurav','Sonakshi'],
    'Age':[20,22,23],
    'city':['Delhi','Mumbai','Ahemdabad']}

df1=pd.DataFrame(data)

df1.to_csv("without_indexing.csv",index=False)
print(df1.head())

# %%
# Writing again with index for demo
df.to_csv('custom_index.csv')

# Reading with index_col
df_indexed = pd.read_csv('custom_index.csv', index_col=0)
print(df_indexed)
# Out:
#                 Name  Age       City
# 0  Prince chandravat   25      Delhi
# 1      Shruti khapra   30     Mumbai
# 2      Vibhor sharma   22  Bangalore

# %%
# Read only Name and City columns
df_cols = pd.read_csv('without_index.csv', usecols=['Name', 'City'])
print(df_cols)
# Out:
#      Name       City
# 0  Prince      Delhi
# 1  Shruti     Mumbai
# 2  Vibhor  Ahemdabad

# %%
# Write with a pipe separator
df.to_csv('pipe_sep.csv', sep='|', index=False)

# Read with pipe separator
df_pipe = pd.read_csv('pipe_sep.csv', sep='|')
print(df_pipe)
# Out:
#                 Name  Age       City
# 0  Prince chandravat   25      Delhi
# 1      Shruti khapra   30     Mumbai
# 2      Vibhor sharma   22  Bangalore
