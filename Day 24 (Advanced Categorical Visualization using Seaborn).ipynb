# %% [markdown]
# # Notebook 24 (Advanced Categorical Visualization using Seaborn)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Categorical plots-

# %% [raw]
# Categorical scatter plot-
#
# 1)- Strip plot
# 2)- Swarm plot

# %% [raw]
# categorical distribution plot-
#
# 1)- Boxplot
# 2)- Violine plot

# %% [raw]
# Categorical Estimate Plot -> for central tendency
#
# 1)-Barplot
# 1)-Pointplot
# 1)-Countplot

# %%
#Categorical Scatter plot-

# %%
#Strip plot-

# %%
#loading tips dataset
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#loading titanic dataset-
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Distribution of fare by class using stripplot-

sns.stripplot(data=titanic,x='class',y='fare',jitter=0.3,hue='sex')
plt.title('Distrbution of Fare by class')
# Out:
# Text(0.5, 1.0, 'Distrbution of Fare by class')

# %%
# also create with figure level function-

sns.catplot(data=titanic,x='class',y='fare',kind='strip',jitter=0.3,hue='sex')

# %%
#Swarm plot-

# %%
sns.swarmplot(x='pclass', y='age', data=titanic,size=3.5,hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
#Using figure level function-

sns.catplot(data=titanic,x='pclass',y='age',hue='sex',kind='swarm',size=3.5)

# %%
#Categorical distribution plot-

# %%
# Boxplot-

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
#creating a boxplot which represent class and fare -

sns.boxplot(data=titanic,x='class',y='fare',hue='sex',palette=['red', 'green'])
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
#single boxplot-

#age boxplot-
sns.boxplot(data=titanic,y='age')
# Out:
# <Axes: ylabel='age'>

# %%
# (Violineplot = box + Kde plot)

#Violine plot-

# %%
#violin plot on pclass and fare-
sns.violinplot(data=titanic,x='pclass',y='fare',hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
#on tips dataset-

sns.violinplot(data=tips,x='day',y='total_bill',hue='sex',split=True,palette=['blue', 'red'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Category estimate plot-

# %%
#Barplot-

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker')  #men default
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# On titanic dataset-

sns.barplot(data=titanic,x='class',y='age',hue='survived',palette=['violet', 'lightblue'])
plt.title('Survival of passengers by age and class')
plt.show()

# %%
# estimator-  median
sns.barplot(data=titanic,x='class',y='age',hue='survived',estimator=np.median,palette=['skyblue', 'salmon'])
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.barplot(data=titanic,x='class',y='age',hue='survived',estimator=np.max,palette=['skyblue', 'lightgreen'])  #maximum
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
#pointplot-

sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker',ci=None)
# Out:
# C:\Users\Prince Chandravat\AppData\Local\Temp\ipykernel_12448\1357509676.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker',ci=None)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#counplot-

sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#faceting using catplot-

sns.catplot(data=tips,x='sex',y='total_bill',kind='box',row='time',col='smoker',palette=['skyblue','orange'])
# Out:
# C:\Users\Prince Chandravat\AppData\Local\Temp\ipykernel_12448\921765781.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=tips,x='sex',y='total_bill',kind='box',row='time',col='smoker',palette=['skyblue','orange'])

# %%
#Regression plot-

# %%
sns.regplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#Lmplot-

sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')
plt.show()

# %%
#Residplot-

sns.residplot(data=tips,x='total_bill',y='tip',color='darkblue')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#Pairplot & PairGrid-

# %%
#Pairplot-
sns.pairplot(tips,hue='sex')

# %%
flight=sns.load_dataset('flights')
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# Plotting pairwise Relationship - (Pairplot , PairGrid)

sns.pairplot(flight,hue='month')

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#PairGrid-

x=sns.PairGrid(iris,hue='species')
x.map(sns.scatterplot)

# %%
#Pairplot-

y=sns.PairGrid(iris,hue='species')
y.map_diag(sns.histplot)
y.map_offdiag(sns.scatterplot)

# %%
#PairGrid with customization -

m=sns.PairGrid(data=iris,hue='species')
m.map_diag(sns.histplot)
m.map_upper(sns.kdeplot)
m.map_lower(sns.scatterplot)

# %%
# vars in PairGrid-

m=sns.PairGrid(data=iris,hue='species',vars=['sepal_width','petal_width'])  # vars used for specify columns
m.map_diag(sns.histplot)
m.map_upper(sns.kdeplot)
m.map_lower(sns.scatterplot)

# %%
#Jointplot-

# %%
sns.jointplot(tips,x='total_bill',y='tip',hue='sex')  #scatter default

# %%
sns.jointplot(tips,x='total_bill',y='tip',hue='sex',kind='hist')   #histogram

# %%
sns.jointplot(tips,x='total_bill',y='tip',hue='sex',kind='kde')  #kde

# %%
# JointGrid-

# %%
g=sns.JointGrid(tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.boxplot)

# %%
g=sns.JointGrid(tips,x='total_bill',y='tip',hue='sex')
g.plot(sns.scatterplot,sns.barplot)

# %%
g=sns.JointGrid(tips,x='total_bill',y='tip',hue='sex')
g.plot(sns.kdeplot,sns.violinplot)
