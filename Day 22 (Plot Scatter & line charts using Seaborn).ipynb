# %% [markdown]
# # Notebook 23 (Plot Scatter & Line chartusing Seaborn)-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [raw]
# #These are 2 methods for creating plots-
#
# 1)- axes level function-
# 2)- figure level function-

# %%
# Scatter plot-

# %%
#loading a dataset-
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Scatter plot (using axes level function)-

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Scatter plot (using figure level function)-

# %%
sns.relplot(data=df,x='total_bill',y='tip',kind='scatter',hue='sex',style='time',size='size')

# %%
employee_data=pd.read_csv(r"C:\Users\Prince Chandravat\OneDrive\Videos\Documents\DATASETS\employee salary dataset\synthetic_salary_dataset.csv")
employee_data
# Out:
#                       Position  YearsExperience EducationLevel       Industry  \
# 0                 NLP Engineer              2.8            PhD        Finance
# 1    Machine Learning Engineer             12.3      Bachelors        Finance
# 2     Computer Vision Engineer              4.8      Bachelors  Manufacturing
# 3    Machine Learning Engineer              1.7      Bachelors             IT
# 4               MLOps Engineer             12.4        Masters     Healthcare
# ..                         ...              ...            ...            ...
# 495   Computer Vision Engineer              8.0            PhD        Finance
# 496              AI Researcher              8.5            PhD             IT
# 497               Data Analyst              2.1      Bachelors         Retail
# 498             Data Scientist              5.5            PhD  Manufacturing
# 499               Data Analyst              6.2      Bachelors     Healthcare
#
#       Location  Salary(INR)
# ...

# %%
#Positions with avg salary-

position=employee_data.groupby('Position')['Salary(INR)'].mean().reset_index()
position
# Out:
#                         Position   Salary(INR)
# 0                  AI Researcher  1.550468e+06
# 1              Big Data Engineer  1.566711e+06
# 2  Business Intelligence Analyst  1.502100e+06
# 3       Computer Vision Engineer  1.574613e+06
# 4                   Data Analyst  1.573771e+06
# 5                 Data Scientist  1.445607e+06
# 6                 MLOps Engineer  1.438840e+06
# 7      Machine Learning Engineer  1.635213e+06
# 8                   NLP Engineer  1.415318e+06
# 9              Software Engineer  1.547458e+06

# %%
sns.relplot(data=employee_data,x=employee_data['Position'],y=employee_data['Salary(INR)'],kind='scatter',size='YearsExperience')
plt.xticks(rotation=85)
plt.show()

# %%
#Top High salray positions-

employee_data.groupby('Position')['Salary(INR)'].mean().sort_values(ascending=False).reset_index()
# Out:
#                         Position   Salary(INR)
# 0      Machine Learning Engineer  1.635213e+06
# 1       Computer Vision Engineer  1.574613e+06
# 2                   Data Analyst  1.573771e+06
# 3              Big Data Engineer  1.566711e+06
# 4                  AI Researcher  1.550468e+06
# 5              Software Engineer  1.547458e+06
# 6  Business Intelligence Analyst  1.502100e+06
# 7                 Data Scientist  1.445607e+06
# 8                 MLOps Engineer  1.438840e+06
# 9                   NLP Engineer  1.415318e+06

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=employee_data, x='Position', y='Salary(INR)',align='edge',color='teal')
plt.xticks(rotation=85)
plt.title("Salary Distribution by Position")
plt.show()

# %%
#loading a dataset -
gap=px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
india=gap[gap['country']=='India']
india
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
#ploting a line plot-  (by axes leve function)

sns.lineplot(data=india,x='year',y='lifeExp',hue='country')
plt.grid()

# %%
# (by figure level function)-

sns.relplot(data=india,x='year',y='lifeExp',kind='line')
plt.grid()

# %%
sample=gap[gap['country'].isin(['India','Italy','Brazil'])]
sample
# Out:
#     country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168  Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169  Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170  Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171  Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172  Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173  Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174  Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175  Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176  Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177  Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178  Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179  Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
#ploting line graph by axes level func-

sns.lineplot(data=sample,x='year',y='lifeExp',hue='country',style='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
#ploting line graph by figure level func-


sns.relplot(kind='line',data=sample,x='year',y='lifeExp',hue='country',style='continent')
