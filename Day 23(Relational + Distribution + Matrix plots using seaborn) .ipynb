# %% [markdown]
# # Notebook 23 (Relational + Distribution + Matrix plots using seaborn)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#loading a dataset-
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Face plot-

# %%
# Creating scatter plot on sex based columns using seaborn-

sns.relplot(kind='scatter',data=df,x='total_bill',y='tip',col='sex')

# %%
#Creating scatter plot -

# columns= 'sex'
# row='day'

sns.relplot(kind='scatter',data=df,x='total_bill',y='tip',col='sex',row='day')

# %%
gap=px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#col_wrap-

sns.relplot(kind='scatter',data=gap,x='lifeExp',y='gdpPercap',col='year',col_wrap=3)

# %%
# loading a dataset:-

car=pd.read_csv(r"C:\Users\Prince Chandravat\OneDrive\Videos\Documents\DATASETS\Auto-mpg dataset\auto-mpg.csv")
car
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#Cleaning the dataset-

car['horsepower'] = pd.to_numeric(car['horsepower'],errors='coerce')

origin_map = {1: 'USA', 2: 'Europe', 3: 'Japan'}
car['origin'] = car['origin'].replace(origin_map
                                     )
df.dropna(inplace=True)  # Drop rows with any missing values

# %% [markdown]
# # Some practice of relational plotting-

# %%
# relationship between weight and mpg-


plt.figure(figsize=(14,7))
sns.relplot(kind='scatter',data=car,x='mpg',y='weight',hue='origin',size='weight')

plt.title('Fuel Efficiency (mpg) vs Car Weight')
plt.grid()
plt.show()

# %%
# relationship between horsepower and mpg-

plt.figure(figsize=(14,6))
sns.relplot(kind='scatter',data=car,x='horsepower',y='mpg',size='weight',hue='origin',style='cylinders')

# %%
# Clustering of Cars by Origin: Weight vs. Acceleration (Size = MPG)-

#figure-
plt.figure(figsize=(10, 6))

#plotting-
sns.scatterplot(data=car,x='weight',y='acceleration',hue='origin',size='mpg',sizes=(40, 200),palette='deep',alpha=0.7)
plt.title('Clustering of Cars by Origin: Weight vs. Acceleration (Size = MPG)')

plt.grid(True)
plt.show()

# %%
# Relationship between horsepower and mpg-

plt.figure(figsize=(10, 6))

sns.scatterplot(data=car,x='horsepower',y='mpg',size='acceleration',sizes=(30, 300),hue='origin',marker='d')

plt.grid()
plt.show()

# %% [markdown]
# # Distribution plots-

# %% [raw]
# 1- used for univariate anlysis
# 2- used to find out the distribution
# 3- Range of the observation
# 4- Central tendency

# %% [raw]
# # Plots under distribution plot-
# 1-Histogram
# 2-Kdeplot
# 3-rugplot

# %%
#Axes level function- displot
#figure level function- histplot,kdeplot,rugplot

# %%
#Histogram-

# %%
# Create a histogram based on horsepower-

sns.displot(data=car,x='horsepower',kind='hist',bins=20)

# %%
#Create a histogram based on origin-

sns.displot(data=car,x='model year',kind='hist',bins=10,color='slategray')

plt.show()

# %%
sns.displot(data=car,x='horsepower',kind='hist')
plt.show()

# %%
sns.displot(data=car,x='horsepower',kind='hist',hue='origin',col='cylinders',col_wrap=2)
plt.show()

# %%
#Kde Plot-

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# by axes function-

sns.kdeplot(data=df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# by figure function-

sns.displot(data=df,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
#Rugplot-

sns.rugplot(data=df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
# creating rug plot with  kde plot-

sns.kdeplot(data=df,x='total_bill',hue='sex',fill=True)
sns.rugplot(data=df,x='total_bill',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Bivariate Histogram-

#A bivariate histogram bins the data within rectangles that title the plot-
# and then show the count the obseravtion within each rectangle with the fill order-

sns.histplot(data=df,x='total_bill',y='tip')
plt.show()

# %%
car.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year origin                   car name
# 0          70    USA  chevrolet chevelle malibu
# 1          70    USA          buick skylark 320
# 2          70    USA         plymouth satellite
# 3          70    USA              amc rebel sst
# 4          70    USA                ford torino

# %%
sns.histplot(data=car,x='horsepower',y='mpg',color='grey')
plt.show()

# %%
# Bivariate kdeplot-
# a biveriate KDE plot smoothes the (x,y) observations with a 2d gaussian.

sns.kdeplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#bivariate kde plot on car dataset-

sns.kdeplot(data=car,x='horsepower',y='acceleration')
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>

# %%
# some practice question of distribution plots-

adsense=pd.read_csv(r"C:\Users\Prince Chandravat\OneDrive\Videos\Documents\DATASETS\google ads sales dataset\GoogleAds_DataAnalytics_Sales_Uncleaned.csv")
adsense.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       $1892  2024-11-16  hyderabad  desktop
# 1          8.0            0.046       $1679  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       $1624  2024/11/16  hyderabad  Desktop
# 3          6.0              NaN       $1225  2024-11-26  HYDERABAD   tablet
# 4          8.0              NaN       $1091  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# ...

# %%
#histogram (on clicks)- 

sns.histplot(data=adsense,x='Clicks',kde=True,color='teal')
plt.show()

# %% [markdown]
# # Matrix plots-

# %% [markdown]
# 1)- Heatmap plot
# 2)- Cluster plot

# %%
#Heatmap-

# %%
gap.sample(10)
# Out:
#           country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 531        France    Europe  1967   71.550   49569000  12999.917660       FRA
# 795         Japan      Asia  1967   71.430  100825279   9847.788607       JPN
# 716     Indonesia      Asia  1992   62.681  184816000   2383.140898       IDN
# 1390     Slovenia    Europe  2002   76.660    2011497  20660.019360       SVN
# 1476  Switzerland    Europe  1952   69.620    4815000  14734.232750       CHE
# 901         Libya    Africa  1957   45.289    1201578   3448.284395       LBY
# 1042   Mozambique    Africa  2002   44.026   18473780    633.617947       MOZ
# 820         Kenya    Africa  1972   53.559   12044785   1222.359968       KEN
# 790       Jamaica  Americas  2002   72.047    2664659   6994.774861       JAM
# 1687       Zambia    Africa  1987   50.821    7272406   1213.315116       ZMB
#
#       iso_num
# 531       250
# 795       392
# 716       360
# 1390      705
# 1476      756
# 901       434
# ...

# %%
x=gap.pivot_table(index='country',columns='year',values='lifeExp')
x
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
#creating a heatmap of country and lifeExp year-

#figure-
plt.figure(figsize=(15,10))
sns.heatmap(x,cmap='ocean')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#Only European country heatmap-

europe=gap[gap['continent']=='Europe'].pivot_table(index='country',columns='year',values='lifeExp')
europe
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
# ...

# %%
#Plotting heatmap-

plt.figure(figsize=(15,12))  
sns.heatmap(data=europe,cmap='YlGnBu',linewidth=0.5,annot=True)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#Asian countries-

asian=gap[gap['continent']=='Asia'].pivot_table(index='country',columns='year',values='lifeExp')
asian
# Out:
# year                  1952      1957      1962      1967      1972      1977  \
# country
# Afghanistan         28.801  30.33200  31.99700  34.02000  36.08800  38.43800
# Bahrain             50.939  53.83200  56.92300  59.92300  63.30000  65.59300
# Bangladesh          37.484  39.34800  41.21600  43.45300  45.25200  46.92300
# Cambodia            39.417  41.36600  43.41500  45.41500  40.31700  31.22000
# China               44.000  50.54896  44.50136  58.38112  63.11888  63.96736
# Hong Kong, China    60.960  64.75000  67.65000  70.00000  72.00000  73.60000
# India               37.373  40.24900  43.60500  47.19300  50.65100  54.20800
# Indonesia           37.468  39.91800  42.51800  45.96400  49.20300  52.70200
# Iran                44.869  47.18100  49.32500  52.46900  55.23400  57.70200
# Iraq                45.320  48.43700  51.45700  54.45900  56.95000  60.41300
# Israel              65.390  67.84000  69.39000  70.75000  71.63000  73.06000
# ...

# %%
plt.figure(figsize=(15,12))  
sns.heatmap(asian,linewidth=0.5,annot=True)
plt.show()
